# %% [markdown]
#     AUTHOR : Mikael Frenette
#
#     IN THIS TUTORIAL, I WILL INTRODUCE THE BASIC USAGE OF THE MODEL PROPOSED
#     IN THE PAPER "From Reactive to Proactive Volatility Modeling with
#     Hemisphere Neural Networks" by Philippe Goulet Coulombe, Mikael Frenette
#     and Karin Klieber (2023).
#
#     TO SEE IMPLEMENTATION SOURCE CODE, PLEASE SEE THE GITHUB :
#     https://github.com/TheAionxGit/Aionx
#
#     FOR ANY QUESTION PLEASE COMMUNICATE WITH ME:
#      - Mikael Frenette (mik.frenette@gmail.com)
#
#                                   IMPORTANT
#     ***************************************************************************
#
#     PLEASE NOTE THAT THIS IMPLEMENTATION IS SUBJECTED TO LIMITED FLEXIBILITY
#     AND MAY NOT SCALE AS INTENDED. A SECOND TUTORIAL WILL BE
#     AVAILABLE ON THE GITHUB AND WILL LET USERS EXPERIMENT WITH THE 'BASE'
#     FUNCTIONS USED TO DEVELOP THE MODEL.
#
#     THE 'DensityHNN' CLASS IS DESIGNED FOR SMALL DATASETS SUCH AS FRED-MD OR
#     FRED-QD. DO NOT USE THIS CLASS WITH DATA SUBJECTED TO IRREGULAR TIMESTAMPS
#     SUCH AS STOCK MARKET DATA (WHICH HAVE HOLIDAYS), BECAUSE PANDAS CANNOT
#     INFER FROM THEIR TIMESTAMP EASILY. ADDITIONALY, I WOULD RECOMMEND NOT USING
#     THE CLASS ON LARGE DATASET SINCE THIS IMPLEMENTATION DOES NOT SUPPORT A
#     MINIBATCH LEARNING AND LARGE BATCHES MAY QUICKLY LEAD TO MEMORY ERROR.
#
#     FINALLY, THE 'DensityHNN' BASE CODE IS STILL IN DEVELOPMENT AND MORE
#     FUNCTIONALITIES WILL BE ADDED IN THE FUTURE.
#
#     ***************************************************************************

# %%
import pandas as pd
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras

tf.data.experimental.enable_debug_mode()
gpus = tf.config.list_physical_devices(device_type = 'GPU')
if gpus:
    print(gpus)
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True) # let tensorflow control GPU memory usage
else:
    print("No GPU detected.")
    
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import datetime as dt
from arch import arch_model
from arch.__future__ import reindexing
from sklearn.linear_model import LinearRegression

from aionx.models import DensityHNN
from aionx.metrics import RootMeanSquaredError, NominalCoverage, LogScore
from aionx.pipelines import RegressionMatrix

import warnings
warnings.filterwarnings("ignore")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
# **NOTE : 
# - DensityHNN class is designed in a way that it can be run in graph mode.
# - For more information about properties of graph mode, please read tensorflow's documentations:
# - https://www.tensorflow.org/guide/intro_to_graphs

# - by default graph mode is enabled. This will significantly increase the training speed of 
#   neural networks.

# - If one wishes to run the model in eager mode or if the function is causing
#   operation issues, graph mode can be disabled by setting : 

#   tf.config.run_functions_eagerly(True)

tf.config.run_functions_eagerly(False)

# %% [markdown]
# # FORECASTING SETUP
# <br>
#
# - We fit the model from 1961-09-01 until 2006-12-01. The pseudo out-of-sample will be from 2007-01-01 until 2022-12-01.
# <br><br>
# - On the FRED-QD data, we use 2 lags. For FRED-MD, we use 6 lags.
# <br><br>
# - For this example, we will try to predict the US GDP one step in the future (s=1).
#
# <br><br>
# ####  A LITTLE WORD ON THE DATASET
# <br>
# One must use a dataset which index is a DatetimeIndex. Maybe these lines of code can help:
#  <br><br>
# data.set_index('your_date_column_name', inplace=True)
# <br>
# data.index = pd.to_datetime(data.index)

# %%
# Import data
data = pd.read_csv("https://raw.githubusercontent.com/TheAionxGit/Aionx/main/datasets/FREDQD.csv")
data.set_index("date", inplace=True)
data.index = pd.to_datetime(data.index)

TRAIN_START = "1961-01-01"
TRAIN_END   = "2006-12-01"
TEST_START  = "2007-01-01"
TEST_END    = "2022-12-01"

LAGS = 2
H = 1
TARGET = "GDPC1"

# %%
# initialize metrics. These metrics are all callable.
RMSE       = RootMeanSquaredError()
Score      = LogScore()
Coverage68 = NominalCoverage(std=1)
Coverage95 = NominalCoverage(std=2)

# %% [markdown]
# # The objective
# <br><br>
#
# we aim to minimize the following equation using a neural network architecture which contains 2 seperate hemispheres: $h_{m}$ and $h_{v}$.
#
# <br>
#
# $$\min_{\theta_{m}, \theta_{v}}  \sum_{t=1}^T  \frac{\left( y_{t+1} - h_m (\boldsymbol{X}_t;\theta_m)\right)^2 }{h_v(\boldsymbol{X}_t;\theta_v)}  + \log(h_v(\boldsymbol{X}_t;\theta_v))$$
#
# where:
# - $h_{m}$ is the conditional mean hemisphere and $h_{v}$ the conditional volatility hemisphere.
# - $\theta_m$ and $\theta_{v}$ are $h_{m}$ and $h_{v}$ weights respectively.
# - $\boldsymbol{X}_t$ is a set of covariate which, in this example, will be fred-qd data.
#
# Since the conditional volatility is prone to vanishing when the network is entering overfitting territory, we estimate an ensemble of regular fully connected neural networks prior to the HNN. We compute its out-of-bag's mean squared error and use the value as volatility emphasis parameter $\nu$. This parameter will help the HNN's training by mitigating the importance of uncertainty estimates.
# <br><br>
# Since the HNN is also an ensemble of networks, we compute its conditional mean and conditional volatility as follow:
# $${h}_j(\boldsymbol{X}_t;\hat{\theta}_{j}) = \frac{1}{(1-\tau) \times B} \sum_{b=1}^B I({h}_j(\boldsymbol{X}_t;\hat{\theta}_{j,b})\neq  \texttt{NA}){h}_j(\boldsymbol{X}_t;\hat{\theta}_{j,b})  \quad \text{for } j \in \{m, v \}.$$
#
# where:
# - $\tau$ is the sampling rate parameter
# - B is the number of bootstraps.

# %%
HNN = DensityHNN(
     target  = TARGET,        # the target.
     lags    = LAGS,          # Number of lags. (2 for QD 6 for MD)
     horizon = H,             # steps in the futur to forecast. (1 and 4 for QD)
     bootstraps = 200,         # number of bootstrap for the HNN. (1000 in the paper)
     prior_bootstraps = 200,   # number of bootstrap for the prior DNN. (1000 in the paper)
     trends = 100,            # number of trends to use. (100 in the paper)
     sampling_rate = 0.8,     # % of samples in each bootstrap. (0.8 in the paper)
     block_size = 8,          # the size of blocks to bootstrap. (8 for QD 24 for MD)
     epochs = 100,            # number maximal of epoch.
     learning_rate = 1e-3,    # the learning rate parameter for the Adam optimizer. (1e-3 in the paper)
     patience = 15,           # the patience parameter for early stopping. (15 in the paper)
     verbose = 2              # the level of verbosity. (0=None, 1=print model, 2=print network).
)

results = HNN.run(
    data = data,             
    train_start = TRAIN_START,
    train_end = TRAIN_END,
    expanding = False,
    expanding_start = "2007-01-01",
    expanding_steps = 8,
    last_expanding_window = dt.datetime(2019, 12, 1)
)

HNN_preds = results["hnn_forecast"]
prior_dnn_preds = ["dnn_forecast"]
vol_emphasis = results["volatility_emphasis"]

print(f"\n volatility emphasis computed for {TARGET} : {vol_emphasis}")

#---------------------------------
# ONLY WORKS IF expanding = False
#---------------------------------
#conditional_mean_bootstraps = results["hnn_bootstraps"]["conditional_mean"]
#conditional_vol_bootstraps = results["hnn_bootstraps"]["conditional_vol"]
# Out:
# prior_dnn [1/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1915 | val_loss: 0.6754
# prior_dnn [2/200] |█████████-----------| Step: 1/1 | Epoch: 41/100 (41%) | loss: 0.1002 | val_loss: 0.9340
# prior_dnn [3/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.1691 | val_loss: 1.1300
# prior_dnn [4/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2358 | val_loss: 0.8285
# prior_dnn [5/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.1890 | val_loss: 0.9456
# prior_dnn [6/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2242 | val_loss: 0.7044
# prior_dnn [7/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2900 | val_loss: 0.6293
# prior_dnn [8/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2232 | val_loss: 1.0909
# prior_dnn [9/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.1739 | val_loss: 0.8284
# prior_dnn [10/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2547 | val_loss: 1.2685
# prior_dnn [11/200] |██████--------------| Step: 1/1 | Epoch: 28/100 (28%) | loss: 0.1132 | val_loss: 1.1553
# prior_dnn [12/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1315 | val_loss: 1.3107
# prior_dnn [13/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1773 | val_loss: 0.6804
# prior_dnn [14/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: 0.1125 | val_loss: 1.0559
# prior_dnn [15/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2712 | val_loss: 0.5076
# prior_dnn [16/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.1560 | val_loss: 0.6623
# prior_dnn [17/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1718 | val_loss: 0.7142
# prior_dnn [18/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1994 | val_loss: 0.6224
# prior_dnn [19/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: 0.1157 | val_loss: 1.1547
# prior_dnn [20/200] |███████-------------| Step: 1/1 | Epoch: 31/100 (31%) | loss: 0.0917 | val_loss: 0.7257
# prior_dnn [21/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2415 | val_loss: 0.8288
# prior_dnn [22/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1736 | val_loss: 0.7806
# prior_dnn [23/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2178 | val_loss: 0.9555
# prior_dnn [24/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: 0.1082 | val_loss: 1.1559
# prior_dnn [25/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2126 | val_loss: 0.7612
# prior_dnn [26/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.3382 | val_loss: 1.1861
# prior_dnn [27/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2240 | val_loss: 0.6849
# prior_dnn [28/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1142 | val_loss: 0.7061
# prior_dnn [29/200] |███████-------------| Step: 1/1 | Epoch: 32/100 (32%) | loss: 0.1078 | val_loss: 0.5289
# prior_dnn [30/200] |██████--------------| Step: 1/1 | Epoch: 29/100 (29%) | loss: 0.1314 | val_loss: 0.7240
# prior_dnn [31/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.1578 | val_loss: 1.1430
# prior_dnn [32/200] |███████-------------| Step: 1/1 | Epoch: 35/100 (35%) | loss: 0.0831 | val_loss: 0.8345
# prior_dnn [33/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2378 | val_loss: 1.2690
# prior_dnn [34/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2011 | val_loss: 1.0984
# prior_dnn [35/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2971 | val_loss: 1.2884
# prior_dnn [36/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: 0.1134 | val_loss: 0.7935
# prior_dnn [37/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1686 | val_loss: 0.7313
# prior_dnn [38/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2436 | val_loss: 1.1735
# prior_dnn [39/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.1612 | val_loss: 0.7890
# prior_dnn [40/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2628 | val_loss: 1.0507
# prior_dnn [41/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2170 | val_loss: 0.8682
# prior_dnn [42/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.1997 | val_loss: 0.6713
# prior_dnn [43/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2873 | val_loss: 0.5058
# prior_dnn [44/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1629 | val_loss: 0.6367
# prior_dnn [45/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2683 | val_loss: 1.3160
# prior_dnn [46/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: 0.1544 | val_loss: 0.6083
# prior_dnn [47/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.1999 | val_loss: 0.7779
# prior_dnn [48/200] |██████--------------| Step: 1/1 | Epoch: 30/100 (30%) | loss: 0.2974 | val_loss: 0.6034
# prior_dnn [49/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.1239 | val_loss: 1.2316
# prior_dnn [50/200] |██████--------------| Step: 1/1 | Epoch: 29/100 (29%) | loss: 0.1671 | val_loss: 0.4445
# prior_dnn [51/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.4168 | val_loss: 0.5542
# prior_dnn [52/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1620 | val_loss: 1.1507
# prior_dnn [53/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.2626 | val_loss: 0.6020
# prior_dnn [54/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: 0.1225 | val_loss: 1.1559
# prior_dnn [55/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2906 | val_loss: 1.2695
# prior_dnn [56/200] |███████-------------| Step: 1/1 | Epoch: 33/100 (33%) | loss: 0.1246 | val_loss: 0.5193
# prior_dnn [57/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1555 | val_loss: 1.2038
# prior_dnn [58/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2470 | val_loss: 1.1142
# prior_dnn [59/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.2423 | val_loss: 0.6558
# prior_dnn [60/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.3739 | val_loss: 0.9528
# prior_dnn [61/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2938 | val_loss: 0.9943
# prior_dnn [62/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2043 | val_loss: 0.9732
# prior_dnn [63/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.1698 | val_loss: 0.9612
# prior_dnn [64/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2274 | val_loss: 0.5689
# prior_dnn [65/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.1923 | val_loss: 0.9421
# prior_dnn [66/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.3308 | val_loss: 0.7322
# prior_dnn [67/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1223 | val_loss: 0.9230
# prior_dnn [68/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.2271 | val_loss: 0.6813
# prior_dnn [69/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.1572 | val_loss: 0.8686
# prior_dnn [70/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1719 | val_loss: 1.0326
# prior_dnn [71/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1866 | val_loss: 1.1489
# prior_dnn [72/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2045 | val_loss: 0.9643
# prior_dnn [73/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.1670 | val_loss: 1.2544
# prior_dnn [74/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.2260 | val_loss: 0.9620
# prior_dnn [75/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.1971 | val_loss: 1.1903
# prior_dnn [76/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: 0.1322 | val_loss: 0.5120
# prior_dnn [77/200] |███████-------------| Step: 1/1 | Epoch: 34/100 (34%) | loss: 0.0796 | val_loss: 1.2825
# prior_dnn [78/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2170 | val_loss: 0.7893
# prior_dnn [79/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.1571 | val_loss: 0.9956
# prior_dnn [80/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: 0.2038 | val_loss: 1.5358
# prior_dnn [81/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.1468 | val_loss: 0.8451
# prior_dnn [82/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: 0.1174 | val_loss: 1.2065
# prior_dnn [83/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.1897 | val_loss: 0.6333
# prior_dnn [84/200] |██████--------------| Step: 1/1 | Epoch: 30/100 (30%) | loss: 0.1399 | val_loss: 0.7716
# prior_dnn [85/200] |███████-------------| Step: 1/1 | Epoch: 33/100 (33%) | loss: 0.1036 | val_loss: 0.6160
# prior_dnn [86/200] |██████--------------| Step: 1/1 | Epoch: 29/100 (29%) | loss: 0.1287 | val_loss: 0.5904
# prior_dnn [87/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: 0.1497 | val_loss: 0.9368
# prior_dnn [88/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.1564 | val_loss: 0.7772
# prior_dnn [89/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.1800 | val_loss: 0.9195
# prior_dnn [90/200] |████████------------| Step: 1/1 | Epoch: 39/100 (39%) | loss: 0.0823 | val_loss: 0.6745
# prior_dnn [91/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2883 | val_loss: 0.6447
# prior_dnn [92/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1625 | val_loss: 0.6339
# prior_dnn [93/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2049 | val_loss: 0.8193
# prior_dnn [94/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.2662 | val_loss: 0.6455
# prior_dnn [95/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2778 | val_loss: 0.8271
# prior_dnn [96/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2236 | val_loss: 0.5599
# prior_dnn [97/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2502 | val_loss: 1.1678
# prior_dnn [98/200] |███████-------------| Step: 1/1 | Epoch: 34/100 (34%) | loss: 0.0755 | val_loss: 0.9846
# prior_dnn [99/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2826 | val_loss: 0.8577
# prior_dnn [100/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: 0.4055 | val_loss: 0.9288
# prior_dnn [101/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.1900 | val_loss: 0.9540
# prior_dnn [102/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2281 | val_loss: 0.9168
# prior_dnn [103/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2694 | val_loss: 0.4953
# prior_dnn [104/200] |████████████--------| Step: 1/1 | Epoch: 56/100 (56%) | loss: 0.0519 | val_loss: 1.0179
# prior_dnn [105/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.2040 | val_loss: 0.4843
# prior_dnn [106/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: 0.2142 | val_loss: 0.5066
# prior_dnn [107/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2466 | val_loss: 0.8582
# prior_dnn [108/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1647 | val_loss: 0.5722
# prior_dnn [109/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2799 | val_loss: 0.4697
# prior_dnn [110/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.1546 | val_loss: 0.5953
# prior_dnn [111/200] |███████-------------| Step: 1/1 | Epoch: 35/100 (35%) | loss: 0.1041 | val_loss: 0.8550
# prior_dnn [112/200] |███████-------------| Step: 1/1 | Epoch: 34/100 (34%) | loss: 0.1111 | val_loss: 0.6863
# prior_dnn [113/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1536 | val_loss: 0.8294
# prior_dnn [114/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.1646 | val_loss: 0.6776
# prior_dnn [115/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.3705 | val_loss: 0.7673
# prior_dnn [116/200] |███████-------------| Step: 1/1 | Epoch: 34/100 (34%) | loss: 0.1317 | val_loss: 0.5572
# prior_dnn [117/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.1983 | val_loss: 0.9171
# prior_dnn [118/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1510 | val_loss: 1.2217
# prior_dnn [119/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: 0.1335 | val_loss: 0.7200
# prior_dnn [120/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2226 | val_loss: 0.7781
# prior_dnn [121/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2357 | val_loss: 0.6249
# prior_dnn [122/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.2191 | val_loss: 0.7527
# prior_dnn [123/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.3667 | val_loss: 0.8676
# prior_dnn [124/200] |██████--------------| Step: 1/1 | Epoch: 29/100 (29%) | loss: 0.0911 | val_loss: 0.9029
# prior_dnn [125/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.1732 | val_loss: 0.9110
# prior_dnn [126/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.3038 | val_loss: 0.5991
# prior_dnn [127/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.1928 | val_loss: 0.4940
# prior_dnn [128/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.2292 | val_loss: 0.8269
# prior_dnn [129/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1512 | val_loss: 1.0788
# prior_dnn [130/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2231 | val_loss: 0.6566
# prior_dnn [131/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1629 | val_loss: 0.6956
# prior_dnn [132/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.2083 | val_loss: 0.9699
# prior_dnn [133/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.1894 | val_loss: 0.8779
# prior_dnn [134/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.1887 | val_loss: 1.1829
# prior_dnn [135/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.1653 | val_loss: 0.8604
# prior_dnn [136/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2369 | val_loss: 0.6578
# prior_dnn [137/200] |███████-------------| Step: 1/1 | Epoch: 34/100 (34%) | loss: 0.1500 | val_loss: 0.9019
# prior_dnn [138/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: 0.1495 | val_loss: 1.1441
# prior_dnn [139/200] |███████-------------| Step: 1/1 | Epoch: 33/100 (33%) | loss: 0.0746 | val_loss: 0.6210
# prior_dnn [140/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.2183 | val_loss: 1.0272
# prior_dnn [141/200] |███████████---------| Step: 1/1 | Epoch: 54/100 (54%) | loss: 0.0547 | val_loss: 1.1667
# prior_dnn [142/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2308 | val_loss: 1.0344
# prior_dnn [143/200] |███████-------------| Step: 1/1 | Epoch: 31/100 (31%) | loss: 0.2042 | val_loss: 1.0145
# prior_dnn [144/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.1507 | val_loss: 0.4642
# prior_dnn [145/200] |███████-------------| Step: 1/1 | Epoch: 32/100 (32%) | loss: 0.1109 | val_loss: 0.4335
# prior_dnn [146/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.3135 | val_loss: 0.9183
# prior_dnn [147/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: 0.1292 | val_loss: 1.1885
# prior_dnn [148/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2838 | val_loss: 0.7723
# prior_dnn [149/200] |████████------------| Step: 1/1 | Epoch: 40/100 (40%) | loss: 0.0694 | val_loss: 0.6984
# prior_dnn [150/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: 0.1078 | val_loss: 1.1232
# prior_dnn [151/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: 0.0973 | val_loss: 1.0791
# prior_dnn [152/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.3145 | val_loss: 0.7966
# prior_dnn [153/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.2088 | val_loss: 0.4560
# prior_dnn [154/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2245 | val_loss: 0.9323
# prior_dnn [155/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.1447 | val_loss: 1.0574
# prior_dnn [156/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.1727 | val_loss: 1.0945
# prior_dnn [157/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.4761 | val_loss: 0.5423
# prior_dnn [158/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.1704 | val_loss: 0.7585
# prior_dnn [159/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1856 | val_loss: 0.7569
# prior_dnn [160/200] |███████-------------| Step: 1/1 | Epoch: 31/100 (31%) | loss: 0.1034 | val_loss: 0.6637
# prior_dnn [161/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.1994 | val_loss: 1.0816
# prior_dnn [162/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.1882 | val_loss: 0.5919
# prior_dnn [163/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.2429 | val_loss: 0.5912
# prior_dnn [164/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.2822 | val_loss: 1.5114
# prior_dnn [165/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.2488 | val_loss: 0.6683
# prior_dnn [166/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.2523 | val_loss: 0.7855
# prior_dnn [167/200] |███████-------------| Step: 1/1 | Epoch: 34/100 (34%) | loss: 0.0837 | val_loss: 0.9478
# prior_dnn [168/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.1708 | val_loss: 0.7770
# prior_dnn [169/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.1857 | val_loss: 0.9003
# prior_dnn [170/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.3699 | val_loss: 0.8891
# prior_dnn [171/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1868 | val_loss: 1.1023
# prior_dnn [172/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2971 | val_loss: 0.9823
# prior_dnn [173/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2581 | val_loss: 1.0552
# prior_dnn [174/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.1609 | val_loss: 0.9110
# prior_dnn [175/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.3640 | val_loss: 0.8313
# prior_dnn [176/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2412 | val_loss: 0.7957
# prior_dnn [177/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.4159 | val_loss: 0.6454
# prior_dnn [178/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.2930 | val_loss: 0.9185
# prior_dnn [179/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.2276 | val_loss: 0.7641
# prior_dnn [180/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.1544 | val_loss: 0.8797
# prior_dnn [181/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1581 | val_loss: 0.9002
# prior_dnn [182/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1488 | val_loss: 0.7241
# prior_dnn [183/200] |█████████-----------| Step: 1/1 | Epoch: 42/100 (42%) | loss: 0.0949 | val_loss: 0.7481
# prior_dnn [184/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: 0.1093 | val_loss: 0.7696
# prior_dnn [185/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.2478 | val_loss: 0.6007
# prior_dnn [186/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.1730 | val_loss: 1.1101
# prior_dnn [187/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2466 | val_loss: 0.5018
# prior_dnn [188/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: 0.1626 | val_loss: 1.4319
# prior_dnn [189/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1521 | val_loss: 0.5610
# prior_dnn [190/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.1464 | val_loss: 0.9757
# prior_dnn [191/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: 0.5538 | val_loss: 0.4402
# prior_dnn [192/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.1798 | val_loss: 0.5546
# prior_dnn [193/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.1551 | val_loss: 0.8705
# prior_dnn [194/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: 0.1659 | val_loss: 1.0637
# prior_dnn [195/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2680 | val_loss: 0.7407
# prior_dnn [196/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.1372 | val_loss: 1.2357
# prior_dnn [197/200] |████----------------| Step: 1/1 | Epoch: 17/100 (17%) | loss: 0.1997 | val_loss: 0.6418
# prior_dnn [198/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: 0.1301 | val_loss: 0.4429
# prior_dnn [199/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2881 | val_loss: 1.2115
# prior_dnn [200/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.1788 | val_loss: 0.5353
#  completed in 00:01:43
# density_hnn [1/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.9376 | val_loss: 13.2317
# density_hnn [2/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.5852 | val_loss: 0.9076
# density_hnn [3/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.7249 | val_loss: 1.5126
# density_hnn [4/200] |███████-------------| Step: 1/1 | Epoch: 31/100 (31%) | loss: -0.1323 | val_loss: 1.6347
# density_hnn [5/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.4580 | val_loss: 5.5334
# density_hnn [6/200] |███████████---------| Step: 1/1 | Epoch: 55/100 (55%) | loss: -1.2846 | val_loss: 0.19669
# density_hnn [7/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.6045 | val_loss: 0.7445
# density_hnn [8/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.3939 | val_loss: 2.4853
# density_hnn [9/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.3750 | val_loss: 0.4668
# density_hnn [10/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.6366 | val_loss: 12.2860
# density_hnn [11/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.1137 | val_loss: 0.8305
# density_hnn [12/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.5673 | val_loss: 1.8363
# density_hnn [13/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: -0.7086 | val_loss: 1.2223
# density_hnn [14/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.6822 | val_loss: 0.5557
# density_hnn [15/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.9067 | val_loss: 3.3088
# density_hnn [16/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.3834 | val_loss: 0.5895
# density_hnn [17/200] |███████-------------| Step: 1/1 | Epoch: 31/100 (31%) | loss: -0.6792 | val_loss: 5.4406
# density_hnn [18/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.5485 | val_loss: 0.5076
# density_hnn [19/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.3963 | val_loss: 1.6857
# density_hnn [20/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.5168 | val_loss: 0.3124
# density_hnn [21/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: -0.4674 | val_loss: 1.8357
# density_hnn [22/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: -0.4246 | val_loss: 8.4153
# density_hnn [23/200] |████████------------| Step: 1/1 | Epoch: 39/100 (39%) | loss: -0.8099 | val_loss: 6.8198
# density_hnn [24/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.5916 | val_loss: 0.9726
# density_hnn [25/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.3518 | val_loss: 1.1914
# density_hnn [26/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.4301 | val_loss: 0.2492
# density_hnn [27/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: -0.4345 | val_loss: 1.1362
# density_hnn [28/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: -0.5727 | val_loss: 1.5859
# density_hnn [29/200] |██████--------------| Step: 1/1 | Epoch: 29/100 (29%) | loss: -0.8627 | val_loss: 0.8491
# density_hnn [30/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.1618 | val_loss: 1.0661
# density_hnn [31/200] |████████------------| Step: 1/1 | Epoch: 36/100 (36%) | loss: -1.0886 | val_loss: 0.21184
# density_hnn [32/200] |████████------------| Step: 1/1 | Epoch: 36/100 (36%) | loss: -0.5202 | val_loss: 0.20642
# density_hnn [33/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.7213 | val_loss: 0.8694
# density_hnn [34/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.0391 | val_loss: -0.0839
# density_hnn [35/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: -0.3114 | val_loss: 5.3864
# density_hnn [36/200] |███████-------------| Step: 1/1 | Epoch: 31/100 (31%) | loss: -1.1428 | val_loss: 2.0944
# density_hnn [37/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.6127 | val_loss: 1.3860
# density_hnn [38/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: -0.5281 | val_loss: 7.0731
# density_hnn [39/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.6642 | val_loss: 0.8350
# density_hnn [40/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: 0.3226 | val_loss: 1.33960
# density_hnn [41/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: 0.1528 | val_loss: -0.0237
# density_hnn [42/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.2995 | val_loss: 0.1664
# density_hnn [43/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: 0.2824 | val_loss: 0.75875
# density_hnn [44/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.2120 | val_loss: 1.4492
# density_hnn [45/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: -0.8492 | val_loss: 1.4590
# density_hnn [46/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: 1.1253 | val_loss: 6.73727
# density_hnn [47/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.4688 | val_loss: 3.0376
# density_hnn [48/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.6722 | val_loss: 0.9589
# density_hnn [49/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.8749 | val_loss: 1.9976
# density_hnn [50/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.6874 | val_loss: 1.2785
# density_hnn [51/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.4275 | val_loss: 0.0894
# density_hnn [52/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.6107 | val_loss: 3.8546
# density_hnn [53/200] |███████-------------| Step: 1/1 | Epoch: 32/100 (32%) | loss: -0.4166 | val_loss: 1.33794
# density_hnn [54/200] |██████████----------| Step: 1/1 | Epoch: 48/100 (48%) | loss: -1.1591 | val_loss: 18.5093
# density_hnn [55/200] |██████--------------| Step: 1/1 | Epoch: 29/100 (29%) | loss: -0.5883 | val_loss: 0.4230
# density_hnn [56/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: 0.9312 | val_loss: 2.76772
# density_hnn [57/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.0692 | val_loss: 0.5616
# density_hnn [58/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: -0.3626 | val_loss: 4.7857
# density_hnn [59/200] |██████--------------| Step: 1/1 | Epoch: 28/100 (28%) | loss: -0.8707 | val_loss: 17.1487
# density_hnn [60/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.6377 | val_loss: 5.7812
# density_hnn [61/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.4805 | val_loss: 2.7578
# density_hnn [62/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.6555 | val_loss: 1.6813
# density_hnn [63/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.5839 | val_loss: 1.0971
# density_hnn [64/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.6485 | val_loss: 2.0354
# density_hnn [65/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.1467 | val_loss: 1.1552
# density_hnn [66/200] |██████--------------| Step: 1/1 | Epoch: 30/100 (30%) | loss: -0.8639 | val_loss: 2.0101
# density_hnn [67/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: -0.4776 | val_loss: 0.5350
# density_hnn [68/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.6656 | val_loss: 1.5169
# density_hnn [69/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.5179 | val_loss: 0.2292
# density_hnn [70/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.3791 | val_loss: 0.0953
# density_hnn [71/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.4153 | val_loss: 1.5083
# density_hnn [72/200] |███████-------------| Step: 1/1 | Epoch: 33/100 (33%) | loss: -0.8422 | val_loss: 13.8142
# density_hnn [73/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.2380 | val_loss: 0.7674
# density_hnn [74/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.7982 | val_loss: 2.9109
# density_hnn [75/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.0582 | val_loss: 0.42944
# density_hnn [76/200] |███████-------------| Step: 1/1 | Epoch: 34/100 (34%) | loss: -0.8746 | val_loss: 0.6107
# density_hnn [77/200] |███████-------------| Step: 1/1 | Epoch: 32/100 (32%) | loss: -1.1354 | val_loss: 4.4146
# density_hnn [78/200] |████████------------| Step: 1/1 | Epoch: 37/100 (37%) | loss: -0.7097 | val_loss: 0.00346
# density_hnn [79/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.2374 | val_loss: 5.8459
# density_hnn [80/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.2468 | val_loss: 0.3621
# density_hnn [81/200] |██████--------------| Step: 1/1 | Epoch: 29/100 (29%) | loss: -0.8553 | val_loss: 1.41917
# density_hnn [82/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.3034 | val_loss: 1.9653
# density_hnn [83/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.5561 | val_loss: 0.17631
# density_hnn [84/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.2877 | val_loss: 0.7267
# density_hnn [85/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.4706 | val_loss: 5.5238
# density_hnn [86/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.4442 | val_loss: 0.11961
# density_hnn [87/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.4572 | val_loss: 5.6804
# density_hnn [88/200] |████████------------| Step: 1/1 | Epoch: 40/100 (40%) | loss: -1.2029 | val_loss: 9.7368
# density_hnn [89/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.5504 | val_loss: 7.9757
# density_hnn [90/200] |███████-------------| Step: 1/1 | Epoch: 32/100 (32%) | loss: -0.3164 | val_loss: 0.4562
# density_hnn [91/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.4423 | val_loss: 2.0627
# density_hnn [92/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.3626 | val_loss: 1.1403
# density_hnn [93/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: 0.3961 | val_loss: 2.92934
# density_hnn [94/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: 0.3514 | val_loss: 5.74667
# density_hnn [95/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.5527 | val_loss: 3.6657
# density_hnn [96/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.6430 | val_loss: 0.6430
# density_hnn [97/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.6909 | val_loss: 0.2762
# density_hnn [98/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.4613 | val_loss: 2.3690
# density_hnn [99/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 0.2268 | val_loss: 2.16882
# density_hnn [100/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.7336 | val_loss: 2.8013
# density_hnn [101/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.3908 | val_loss: 1.5183
# density_hnn [102/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.4780 | val_loss: 0.7349
# density_hnn [103/200] |██████--------------| Step: 1/1 | Epoch: 28/100 (28%) | loss: 0.0816 | val_loss: 0.44885
# density_hnn [104/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.8968 | val_loss: 4.1914
# density_hnn [105/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.6966 | val_loss: 3.1162
# density_hnn [106/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.0139 | val_loss: 0.8467
# density_hnn [107/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.3487 | val_loss: 0.9320
# density_hnn [108/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.1123 | val_loss: 1.1827
# density_hnn [109/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: -0.6646 | val_loss: 8.5170
# density_hnn [110/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: -0.6992 | val_loss: 4.2515
# density_hnn [111/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: 0.0144 | val_loss: 2.08916
# density_hnn [112/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.7711 | val_loss: 0.10641
# density_hnn [113/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.1293 | val_loss: 1.5850
# density_hnn [114/200] |██████--------------| Step: 1/1 | Epoch: 30/100 (30%) | loss: -0.3507 | val_loss: 0.26770
# density_hnn [115/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.2343 | val_loss: 1.4557
# density_hnn [116/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: -0.6749 | val_loss: 1.0087
# density_hnn [117/200] |████████------------| Step: 1/1 | Epoch: 37/100 (37%) | loss: -0.7461 | val_loss: 10.2746
# density_hnn [118/200] |██████--------------| Step: 1/1 | Epoch: 28/100 (28%) | loss: -0.7967 | val_loss: 2.7425
# density_hnn [119/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.3025 | val_loss: 0.3270
# density_hnn [120/200] |████████------------| Step: 1/1 | Epoch: 38/100 (38%) | loss: -1.1840 | val_loss: 8.9432
# density_hnn [121/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.8132 | val_loss: 2.1400
# density_hnn [122/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.8379 | val_loss: 3.8690
# density_hnn [123/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: -0.6007 | val_loss: 4.2156
# density_hnn [124/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: -0.4214 | val_loss: 3.7596
# density_hnn [125/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.3730 | val_loss: 0.3077
# density_hnn [126/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.4678 | val_loss: 2.0613
# density_hnn [127/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.3080 | val_loss: 1.3125
# density_hnn [128/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.3334 | val_loss: 2.8935
# density_hnn [129/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.6699 | val_loss: 3.6286
# density_hnn [130/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.5323 | val_loss: 1.7463
# density_hnn [131/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: -0.6301 | val_loss: 4.4752
# density_hnn [132/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.3567 | val_loss: 1.4517
# density_hnn [133/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.5807 | val_loss: 0.5616
# density_hnn [134/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.2332 | val_loss: 1.8382
# density_hnn [135/200] |████████------------| Step: 1/1 | Epoch: 38/100 (38%) | loss: -0.5487 | val_loss: 1.83932
# density_hnn [136/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: 0.0420 | val_loss: 0.65026
# density_hnn [137/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.6162 | val_loss: 1.7880
# density_hnn [138/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.1145 | val_loss: 2.2825
# density_hnn [139/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.5512 | val_loss: 3.5043
# density_hnn [140/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.4135 | val_loss: 0.5562
# density_hnn [141/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.2572 | val_loss: 0.24409
# density_hnn [142/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: -0.5776 | val_loss: 3.1624
# density_hnn [143/200] |██████--------------| Step: 1/1 | Epoch: 28/100 (28%) | loss: -0.4549 | val_loss: 5.4964
# density_hnn [144/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: 0.2828 | val_loss: 1.55955
# density_hnn [145/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.2405 | val_loss: 3.2713
# density_hnn [146/200] |████████------------| Step: 1/1 | Epoch: 39/100 (39%) | loss: -0.3094 | val_loss: 0.2669
# density_hnn [147/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.4851 | val_loss: 3.00370
# density_hnn [148/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.2002 | val_loss: 0.7573
# density_hnn [149/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.5183 | val_loss: 3.5000
# density_hnn [150/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.6316 | val_loss: 3.2025
# density_hnn [151/200] |█████████-----------| Step: 1/1 | Epoch: 45/100 (45%) | loss: -0.9149 | val_loss: 0.25504
# density_hnn [152/200] |███████-------------| Step: 1/1 | Epoch: 34/100 (34%) | loss: 0.4151 | val_loss: 1.35190
# density_hnn [153/200] |█████████████-------| Step: 1/1 | Epoch: 63/100 (63%) | loss: -0.6543 | val_loss: 0.22816
# density_hnn [154/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.2965 | val_loss: 1.3811
# density_hnn [155/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: 1.3345 | val_loss: 0.89226
# density_hnn [156/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.1067 | val_loss: 2.1101
# density_hnn [157/200] |███████-------------| Step: 1/1 | Epoch: 33/100 (33%) | loss: -0.5067 | val_loss: 0.9805
# density_hnn [158/200] |█████████-----------| Step: 1/1 | Epoch: 43/100 (43%) | loss: -0.9779 | val_loss: 2.2305
# density_hnn [159/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.1797 | val_loss: 0.9403
# density_hnn [160/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.6054 | val_loss: 0.6011
# density_hnn [161/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.5001 | val_loss: 2.0854
# density_hnn [162/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: -0.5493 | val_loss: 5.6439
# density_hnn [163/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.5721 | val_loss: 4.2182
# density_hnn [164/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.5473 | val_loss: 1.3287
# density_hnn [165/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.6089 | val_loss: 0.7464
# density_hnn [166/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.6650 | val_loss: 0.3533
# density_hnn [167/200] |███████-------------| Step: 1/1 | Epoch: 32/100 (32%) | loss: -0.9374 | val_loss: 2.45510
# density_hnn [168/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: -0.3756 | val_loss: 2.9659
# density_hnn [169/200] |██████--------------| Step: 1/1 | Epoch: 29/100 (29%) | loss: -0.8444 | val_loss: 0.5502
# density_hnn [170/200] |████----------------| Step: 1/1 | Epoch: 16/100 (16%) | loss: -0.1934 | val_loss: 3.0718
# density_hnn [171/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.5206 | val_loss: 1.1982
# density_hnn [172/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.6681 | val_loss: 0.4282
# density_hnn [173/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.1817 | val_loss: 0.5444
# density_hnn [174/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.4075 | val_loss: 0.6132
# density_hnn [175/200] |███████-------------| Step: 1/1 | Epoch: 35/100 (35%) | loss: -1.2841 | val_loss: 2.0713
# density_hnn [176/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: 0.2245 | val_loss: 0.32468
# density_hnn [177/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.6415 | val_loss: 1.2671
# density_hnn [178/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: -0.3495 | val_loss: 13.8149
# density_hnn [179/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.1303 | val_loss: 5.6505
# density_hnn [180/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.2279 | val_loss: 0.7396
# density_hnn [181/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.4484 | val_loss: 5.6970
# density_hnn [182/200] |██████--------------| Step: 1/1 | Epoch: 28/100 (28%) | loss: -0.8251 | val_loss: 2.3410
# density_hnn [183/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.6813 | val_loss: 4.4721
# density_hnn [184/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: -0.7187 | val_loss: 1.8077
# density_hnn [185/200] |██████--------------| Step: 1/1 | Epoch: 26/100 (26%) | loss: -0.8093 | val_loss: 2.7934
# density_hnn [186/200] |████----------------| Step: 1/1 | Epoch: 19/100 (19%) | loss: -0.0144 | val_loss: 2.1370
# density_hnn [187/200] |███████-------------| Step: 1/1 | Epoch: 31/100 (31%) | loss: -0.9700 | val_loss: 1.2215
# density_hnn [188/200] |█████---------------| Step: 1/1 | Epoch: 21/100 (21%) | loss: -0.4196 | val_loss: 2.0564
# density_hnn [189/200] |████----------------| Step: 1/1 | Epoch: 20/100 (20%) | loss: -0.5886 | val_loss: 3.8256
# density_hnn [190/200] |█████---------------| Step: 1/1 | Epoch: 25/100 (25%) | loss: -0.5266 | val_loss: 2.7676
# density_hnn [191/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.4888 | val_loss: 2.9076
# density_hnn [192/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: -0.0299 | val_loss: 1.5633
# density_hnn [193/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: -0.3842 | val_loss: 1.1779
# density_hnn [194/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.6494 | val_loss: 0.1576
# density_hnn [195/200] |████----------------| Step: 1/1 | Epoch: 18/100 (18%) | loss: -0.3006 | val_loss: 1.8123
# density_hnn [196/200] |█████---------------| Step: 1/1 | Epoch: 23/100 (23%) | loss: -0.6109 | val_loss: 1.1048
# density_hnn [197/200] |██████--------------| Step: 1/1 | Epoch: 27/100 (27%) | loss: -0.1436 | val_loss: 0.5714
# density_hnn [198/200] |█████---------------| Step: 1/1 | Epoch: 24/100 (24%) | loss: -0.7029 | val_loss: 1.3021
# density_hnn [199/200] |██████--------------| Step: 1/1 | Epoch: 28/100 (28%) | loss: -0.5002 | val_loss: 0.7036
# density_hnn [200/200] |█████---------------| Step: 1/1 | Epoch: 22/100 (22%) | loss: 0.7375 | val_loss: 2.33152
#  completed in 00:02:31
#
#  volatility emphasis computed for GDPC1 : 0.7466559410095215

# %% [markdown]
# # BENCHMARKS
# <br>
# We use an AR(p) model as benchmark for the Root mean squared error metric.
#
# $$ Y_{t} = \alpha + \sum\limits_{p=1}^{P} \phi_{p} Y_{t-p} + \epsilon_{t} $$
#
# where:
# - $y_t$ is the dependent variable at time $t$,
# - $\alpha$ and $\phi$ are coefficients to estimate
# - $Y_{t-1}$, $Y_{t-2}$, $\ldots$, $Y_{t-P}$ are the lagged values of the dependent variable,
# - $ \epsilon_t $ is the error term.
#
#
# <br>
# We use a Garch(p, q) model as benchmark for comparing density metrics. Please note that we use a Garch model in this tutorial for simplicity. We estimate the Garch by maximizing its log likelikehood.
#
# $$ \ln L = -\frac{T}{2}\ln(2\pi) - \frac{1}{2}\sum\limits_{t=1}^{T}\ln(\sigma^{2}_{t}) - \frac{1}{2} \sum\limits_{t=1}^{T}\frac{ \epsilon^{2}_{t} }{ \sigma_{t}^{2} } $$
#
# where:
# - $\ln L$ is the estimated log likelihood.
# - $\sigma$ is the conditional volatility process.
# - $\epsilon$ are the residuals coming from the conditional mean process.

# %%
# will store metrics here
bench_results = pd.DataFrame()

matrix_generator = RegressionMatrix(targets=[TARGET], in_steps=LAGS, horizon=H)
matrix = matrix_generator(data[[TARGET]], return_dataframe=True).dropna()

# set training inputs
X_train = matrix.loc[TRAIN_START:TRAIN_END, :].drop(TARGET, axis=1)
y_train = matrix.loc[TRAIN_START:TRAIN_END, TARGET]

# create linear regression model
model = LinearRegression()
model.fit(X_train, y_train) # fit the model

# create forecasted indexes
fcst_index = pd.date_range(matrix.index[0],
                           periods=len(matrix),
                           freq=pd.infer_freq(data.index))

AR = pd.DataFrame(
    model.predict(matrix.iloc[:, 1:]), columns=[TARGET], index=fcst_index
)

# align and remove N/A values
merged = pd.concat([matrix[TARGET], AR[TARGET]], axis=1)

# I compute now some necessary metrics from the benchmarks
# by setting squared to false, we get the RMSE.
AR2_train_mse = RMSE(
    merged.loc[TRAIN_START:TRAIN_END].iloc[:, 0],
    merged.loc[TRAIN_START:TRAIN_END].iloc[:, 1]
)
AR2_test1_mse = RMSE(
    merged.loc[TEST_START:"2020-01-01"].iloc[:, 0],
    merged.loc[TEST_START:"2020-01-01"].iloc[:, 1]
)
AR2_test2_mse = RMSE(
    merged.loc[TEST_START:TEST_END].iloc[:, 0],
    merged.loc[TEST_START:TEST_END].iloc[:, 1]
)

# store metrics in a dataframe
bench_results.loc["train set", f"{TARGET}_h{1}"]  = AR2_train_mse
bench_results.loc["val set", f"{TARGET}_h{1}"]  = AR2_test1_mse
bench_results.loc["test set", f"{TARGET}_h{1}"] = AR2_test2_mse

# fit a garch model
garch = arch_model(y=data[TARGET], mean="AR", p=1, q=1, vol = 'GARCH', lags=LAGS,
                            dist = 'normal').fit(disp=False, last_obs=TRAIN_END,
                                                 options={"maxiter":10000,
                                                                "ftol":1e-5,
                                                                "eps":1e-4})

# produce forecast with the garch model
fc = garch.forecast(horizon=1, start = data.index[0+LAGS], align="target")

# keep and transform what is needed.
AR_Garch = pd.DataFrame({
  "mean":fc.mean.iloc[:, -1].squeeze(),
  "volatility":np.sqrt(fc.variance.iloc[:, -1].squeeze())
}, index=fc.mean.index).dropna()

# %%
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 2.0

# plot size
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols =2, figsize=(12, 4))
fig.suptitle(f"{TARGET}", size=20)

target_ax = ax0.plot(data[TARGET], color="midnightblue", linewidth=.7)[0]
mean_ax   = ax0.plot(HNN_preds[f"conditional_mean"], color="#ef3b2c")[0]
garch_ax  = ax1.plot(AR_Garch["volatility"], color="blue")[0]
vol_ax  = ax1.plot(HNN_preds[f"conditional_vol"], color="#ef3b2c")


legend = fig.legend([target_ax, mean_ax, garch_ax],
           labels=[f"Realization", "HNN", "GARCH"],
            loc='upper center', bbox_to_anchor=(0.5, -0.00),
                  fancybox=False, shadow=False, ncol=5, frameon=False,
                  fontsize=10,  prop={"size":15})

ax0.fill_between(HNN_preds.index,
                     HNN_preds[f"conditional_mean"].squeeze()- HNN_preds[f"conditional_vol"].squeeze(), # lower bound
                     HNN_preds[f"conditional_mean"].squeeze() + HNN_preds[f"conditional_vol"].squeeze(), # upper bound
                     color="#ef3b2c", alpha=.2)

title1 = ax0.set_title("Conditional Mean",  backgroundcolor='black', color='white',
                      fontweight="bold",
                size=12, position=(.5, 1.01))
title1._bbox_patch._mutation_aspect = 0.04
title1.get_bbox_patch().set_boxstyle("square", pad=11)

ax0.tick_params(axis="both", labelsize=12)
ax0.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax0.grid(color='grey', alpha=.3)
ax0.margins(x=0.02)
ax0.margins(y=0.02)

if TARGET == "GDPC1":
    ax0.set_ylim((-0.03, 0.03))
    ax1.set_ylim((0.003, .019))

title1 = ax1.set_title("Conditional Volatility",  backgroundcolor='black', color='white',
                      fontweight="bold",
                size=12, position=(.5, 1.01))
title1._bbox_patch._mutation_aspect = 0.04
title1.get_bbox_patch().set_boxstyle("square", pad=10)

ax1.tick_params(axis="both", labelsize=12)
ax1.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax1.grid(color='grey', alpha=.3)
ax1.margins(x=0.02)
ax1.margins(y=0.02)

plt.tight_layout()  
plt.show()

# %% [markdown]
# ### Evaluation metrics used in this tutorial are the following :<br><br>
#
# the root mean squared error (RMSE):
# $$RMSE_{s} = \sqrt{ \frac{1}{T}\sum_{t=1}^{T} (y_{t+s}-\hat{y}_{t+s})^2}$$
# <br><br>
# the log score ($L_{s}$):
# $$L_{s} = - \frac{1}{T}\sum_{T}^{T} \log \left( \varphi (\varepsilon_{t,s}; \hat{\sigma}_{t,s})\right) $$
# <br><br>
# and finally, the nominal coverage which computes the proportion of errors smaller than volatility:
#
# $$cov_{68} = \frac{\sum\limits_{t \in oos}(\epsilon_{t} < \sigma_{t})}{\# oos}$$
# <br>
# $$cov_{95} = \frac{\sum\limits_{t \in oos}(\epsilon_{t} < 2*\sigma_{t})}{\# oos}$$

# %%
metrics = pd.DataFrame()
model_dict = {"HNN":HNN_preds, "GARCH":AR_Garch}
# calcule des rmses qu'on divise par l'indice de référence (les AR(2))
for model, fcst in model_dict.items():
    merged = pd.concat([
        data[TARGET],
        fcst
    ], axis=1).dropna()

    merged.columns = [TARGET, "mean", "vol"]

    train_RMSE = RMSE(
        merged.iloc[:, 0].loc[TRAIN_START:TRAIN_END],
        merged.iloc[:, 1].loc[TRAIN_START:TRAIN_END]
    ) / AR2_train_mse

    test1_RMSE = RMSE(
        merged.iloc[:, 0].loc[TEST_START:"2020-01-01"],
        merged.iloc[:, 1].loc[TEST_START:"2020-01-01"]
    ) / AR2_test1_mse

    test2_RMSE = RMSE(
        merged.iloc[:, 0].loc[TEST_START:TEST_END],
        merged.iloc[:, 1].loc[TEST_START:TEST_END]
    ) / AR2_test2_mse

    train_score = Score(
        merged.loc[TRAIN_START:TRAIN_END, [TARGET]],
        merged.loc[TRAIN_START:TRAIN_END, ["mean", "vol"]]
    )

    test1_score = Score(
        merged.loc[TEST_START:"2020-01-01", TARGET],
        merged.loc[TEST_START:"2020-01-01", ["mean", "vol"]]
    )

    test2_score = Score(
        merged.loc[TEST_START:TEST_END, TARGET],
        merged.loc[TEST_START:TEST_END, ["mean", "vol"]]
    )

    train_cov68 = Coverage68(
        y_true=merged.loc[TRAIN_START:TRAIN_END, TARGET],
        y_pred=merged.loc[TRAIN_START:TRAIN_END, ["mean", "vol"]]
    )

    test1_cov68 = Coverage68(
        y_true=merged.loc[TEST_START:"2020-01-01", TARGET],
        y_pred=merged.loc[TEST_START:"2020-01-01", ["mean", "vol"]]
    )

    test2_cov68 = Coverage68(
        y_true=merged.loc[TEST_START:TEST_END, TARGET],
        y_pred=merged.loc[TEST_START:TEST_END, ["mean", "vol"]]
    )


    train_cov95 = Coverage95(
        y_true=merged.loc[TRAIN_START:TRAIN_END, TARGET],
        y_pred=merged.loc[TRAIN_START:TRAIN_END, ["mean", "vol"]]
    )

    test1_cov95 = Coverage95(
        y_true=merged.loc[TEST_START:"2020-01-01", TARGET],
        y_pred=merged.loc[TEST_START:"2020-01-01", ["mean", "vol"]]
    )

    test2_cov95 = Coverage95(
        y_true=merged.loc[TEST_START:TEST_END, TARGET],
        y_pred=merged.loc[TEST_START:TEST_END, ["mean", "vol"]]
    )


    metrics.loc["RMSE(oob)", model] = train_RMSE
    metrics.loc["RMSE < 2020", model]   = test1_RMSE
    metrics.loc["RMSE", model]  = test2_RMSE
    metrics.loc["Score(oob)", model] = train_score
    metrics.loc["Score < 2020", model]   = test1_score
    metrics.loc["Score", model]  = test2_score

    metrics.loc["coverage 68% oob", model] = train_cov68
    metrics.loc["coverage 68% < 2020", model] = test1_cov68
    metrics.loc["coverage 68% Test set", model] = test2_cov68
    metrics.loc["coverage 95% oob", model] = train_cov95
    metrics.loc["coverage 95% < 2020", model] = test1_cov95
    metrics.loc["coverage 95% Test set", model] = test2_cov95

metrics
# Out:
#                             HNN     GARCH
# RMSE(oob)              0.900664  1.001831
# RMSE < 2020            0.806437  1.007367
# RMSE                   0.997226  1.001421
# Score(oob)            -3.548844 -3.521348
# Score < 2020          -3.886247 -3.716261
# Score                 -1.990555 -2.114522
# coverage 68% oob       0.683333  0.709497
# coverage 68% < 2020    0.884615  0.846154
# coverage 68% Test set  0.796875  0.828125
# coverage 95% oob       0.972222  0.966480
# coverage 95% < 2020    0.980769  0.942308
# coverage 95% Test set  0.937500  0.906250
